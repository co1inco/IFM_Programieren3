# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn

# %% [markdown]
# # Augabe 1

# %%
COLUMN_TEMP_2M = "temperature_2m (°C)"

df = pd.read_csv("herford_weather.csv", parse_dates=['time']).set_index('time')
display(df.index.dtype)
df[:5]
# Out:
# dtype('<M8[ns]')
#                      temperature_2m (°C)  relativehumidity_2m (%)  \
# time
# 1996-01-01 00:00:00                 -2.3                       80
# 1996-01-01 01:00:00                 -2.1                       80
# 1996-01-01 02:00:00                 -2.0                       79
# 1996-01-01 03:00:00                 -2.1                       79
# 1996-01-01 04:00:00                 -2.2                       78
#
#                      dewpoint_2m (°C)  apparent_temperature (°C)  \
# time
# 1996-01-01 00:00:00              -5.3                       -7.2
# 1996-01-01 01:00:00              -5.2                       -7.0
# 1996-01-01 02:00:00              -5.2                       -6.9
# 1996-01-01 03:00:00              -5.3                       -7.0
# 1996-01-01 04:00:00              -5.5                       -7.1
#
#                      pressure_msl (hPa)  surface_pressure (hPa)  \
# time
# 1996-01-01 00:00:00              1003.4                   988.2
# ...

# %%
df[COLUMN_TEMP_2M].plot.line(figsize=(15,5))
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# # Aufgabe 2

# %%
df_2022 = df['2022-01-01':'2022-12-31']
df_2022[:5]
# Out:
#                      temperature_2m (°C)  relativehumidity_2m (%)  \
# time
# 2022-01-01 00:00:00                 12.1                       94
# 2022-01-01 01:00:00                 12.0                       95
# 2022-01-01 02:00:00                 11.9                       95
# 2022-01-01 03:00:00                 11.7                       95
# 2022-01-01 04:00:00                 11.6                       96
#
#                      dewpoint_2m (°C)  apparent_temperature (°C)  \
# time
# 2022-01-01 00:00:00              11.2                        9.7
# 2022-01-01 01:00:00              11.1                        9.5
# 2022-01-01 02:00:00              11.1                       10.3
# 2022-01-01 03:00:00              11.0                       10.1
# 2022-01-01 04:00:00              11.0                        9.9
#
#                      pressure_msl (hPa)  surface_pressure (hPa)  \
# time
# 2022-01-01 00:00:00              1019.9                  1005.2
# ...

# %%
df_2022[COLUMN_TEMP_2M].plot.line(figsize=(15,5))
# Out:
# <Axes: xlabel='time'>

# %%
df_2022_avg = df_2022.resample('d').mean()
df_2022_avg[COLUMN_TEMP_2M].plot.line(figsize=(15,5))
# Out:
# <Axes: xlabel='time'>

# %%
df_2022_avg[:5]
# Out:
#             temperature_2m (°C)  relativehumidity_2m (%)  dewpoint_2m (°C)  \
# time
# 2022-01-01            11.295833                92.875000         10.175000
# 2022-01-02            11.058333                83.458333          8.329167
# 2022-01-03             8.708333                87.833333          6.787500
# 2022-01-04             6.445833                91.750000          5.187500
# 2022-01-05             2.695833                90.916667          1.358333
#
#             apparent_temperature (°C)  pressure_msl (hPa)  \
# time
# 2022-01-01                   9.137500         1022.158333
# 2022-01-02                   7.545833         1012.791667
# 2022-01-03                   4.333333         1007.704167
# 2022-01-04                   3.116667          997.429167
# 2022-01-05                  -2.308333         1000.745833
#
#             surface_pressure (hPa)  precipitation (mm)  rain (mm)  \
# time
# 2022-01-01             1007.420833            0.000000   0.000000
# ...

# %%
df['2022-08-01':'2022-08-01'][COLUMN_TEMP_2M].plot.line(figsize=(15,5))
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# df[...] does not support a single value for selecting the index. To do that, use df.loc

# %%
df.loc['2022-08-01'][COLUMN_TEMP_2M].plot.line(figsize=(15,5))
# Out:
# <Axes: xlabel='time'>

# %%
df_broken = df['2022-08-01':'2022-08-01'] #.drop(pd.to_datetime('2022-08-01 18:00'))
df_broken.loc['2022-08-01 18:00', COLUMN_TEMP_2M] = np.nan # apparently setting a value to nan this way, changes the datatype for some FUCKING reason 
# updated. It magically fixed itself ...
# df_broken.replace(to_replace=pd.to_datetime('2022-08-01 18:00'), value=np.nan, inplace=True)
# df_broken.loc[df_broken[COLUMN_TEMP_2M] == pd.to_datetime('2022-08-01 18:00'), COLUMN_TEMP_2M] = np.nan
display(df_broken[COLUMN_TEMP_2M].dtypes)
display(df_broken[16:19])

df_broken[COLUMN_TEMP_2M].plot.line(figsize=(15,5))
# Out:
# dtype('float64')
#                      temperature_2m (°C)  relativehumidity_2m (%)  \
# time
# 2022-08-01 16:00:00                 21.6                       65
# 2022-08-01 17:00:00                 22.1                       60
# 2022-08-01 18:00:00                  NaN                       57
#
#                      dewpoint_2m (°C)  apparent_temperature (°C)  \
# time
# 2022-08-01 16:00:00              14.8                       22.0
# 2022-08-01 17:00:00              14.0                       22.2
# 2022-08-01 18:00:00              13.2                       22.0
#
#                      pressure_msl (hPa)  surface_pressure (hPa)  \
# time
# 2022-08-01 16:00:00              1018.1                  1003.9
# 2022-08-01 17:00:00              1017.6                  1003.5
# 2022-08-01 18:00:00              1017.4                  1003.3
#
#                      precipitation (mm)  rain (mm)  snowfall (cm)  \
# time
# ...

# %%
df_fixed = df_broken.copy()
mean = df_fixed.mean()

df_fixed[COLUMN_TEMP_2M] = df_fixed[COLUMN_TEMP_2M].fillna(mean[COLUMN_TEMP_2M])
df_fixed[COLUMN_TEMP_2M].plot.line(figsize=(15,5))
# Out:
# <Axes: xlabel='time'>

# %%
df_fixed = df_broken.copy()

df_fixed = df_fixed.ffill()
df_fixed[COLUMN_TEMP_2M].plot.line(figsize=(15,5))
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# # Aufgabe 3

# %%
df['2022-06-01':'2022-06-03'][COLUMN_TEMP_2M]\
    .plot.line(figsize=(15,5))
# Out:
# <Axes: xlabel='time'>

# %%
df['2022-06-01':'2022-06-03'][COLUMN_TEMP_2M]\
    .rolling(window=9, center=True)\
    .mean()\
    .plot.line(figsize=(15,5))
# Out:
# <Axes: xlabel='time'>
