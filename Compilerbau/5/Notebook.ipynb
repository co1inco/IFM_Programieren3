# %% [markdown]
# # Aufgabe 1
#
#
# ```
# First(S)={1,3}
# First(A)={2,€}
# First(1AS)={1}
# First(2AS)={2}
# First(3) = {3}
# First($) = {$}
# ```
#
# ```
# Follow(S) = {1, 3}
# Follow(A) = {1, 3}
# Follow(1AS) = {$, 1, 3}
# Follow(2AS) = {$, 1, 3}
# ```

# %% [markdown]
# # Post mortem
#
# Jede Person beschreibt in der ILIAS-Abgabe individuell(!) die Bearbeitung des jeweiligen Aufgabenblattes
# zurückblickend mit ca. 200 bis 400 Wörtern. Gehen Sie dabei aussagekräftig und nachvollziehbar auf folgende Punkte ein:
#  (a) Zusammenfassung: Was wurde gemacht?
#  (b) Implementierungsdetails: Kurze Beschreibung besonders interessanter Aspekte der Umsetzung.
#  (c) Was war der schwierigste Teil bei der Bearbeitung? Wie haben Sie dieses Problem gelöst?
#  (d) Was haben Sie gelernt oder (besser) verstanden?
#  (e) Team: Mit wem haben Sie zusammengearbeitet?
#  (f) Link zum Repo mit der Lösung
#
#
#
#  * a: Ich habe mir zu erst einen Parser in ANTLR geschrieben, damit ich eine Referenz für meine eigene implementation habe. Den ANTLR Parser habe ich mithilfe einer kleinen stdlib (b) getestet. Danach habe ich auf basis der ANTLR syntax einen eigenen Lexer implementiert. Den Lexer habe ich überprüft, indem ich die Testeingabe Schrittweise der Implementierten Komponenten angepasst habe. Letztendlich musste der Lexer die stdlib ohne fehler Lexer. Das gleiche habe ich dan mit dem Parser Wiederholt.
#  * b: Den Parsers / Lexers habe ich auf Basis meines F# Scheme parsers verwendet. Dieser basiert wiederum auf diesem Guide: https://en.wikibooks.org/wiki/Write_Yourself_a_Scheme_in_48_Hours. Mein Parser mach keinen Lookahead / Backtracking). Um das zu erreichen habe ich allerdings ein wenig getrickst. Mein Parser gibt zwar bool Tokens zurück. Tatsächlich parsed er aber nur ein Atom und schaut im Nachhinein ob der Wert true oder false ist. Ansonsten hat der Parser kein sonderlich tiefes Verständnis von dem Code. Alles ist ein Wert, eine Atom oder eine Liste. Strukturen wie ein if würden dan von einem interpreter analysiert. Das macht wie ich finde am meisten sin, da selbst das if von der syntax her eine Funktion mit 3 Parametern ist (Condition, true branch, false branch).
#  * c: -
#  * d: Ich bin erstaunt, wie simple so ein Lexer / Parser sein kann. Ich hatte den Parser für meine F# implementation Komplizierter in Erinnerung. Allerdings habe ich damals auch noch mit der Sprache selbst gekämpft.
#  * e: -
#  * f: https://github.com/co1inco/IFM_Programieren3/tree/master/Compilerbau/5
